# %%
n = int(input())
t=n
r=0
for i in range(32):
    r=(r<<1)|(n&1)
    n>>=1
print(r)
print(bin(t))
print(bin(r))
# Out:
# 1912602624
# 0b1001110
# 0b1110010000000000000000000000000

# %%
a=5
b=9
print(a,b)
a=a^b
b=a^b
a=a^b
print(a,b)
# Out:
# 5 9
# 9 5

# %%
l=[2,3,4,2,3]
a=0
for i in l:
    a^=i
print(a)
# Out:
# 4

# %%
n=[0,1,3,4,5,6]
a=0
for i in range(len(n)+1):
    a^=i
for i in n:
    a^=i
print(a)
# Out:
# 2

# %%
n=int(input())
print(bin(n))
c=0
while n:
    c+=1
    n=n&(n-1)
    print(bin(n))
print(c)
# Out:
# 0b11011
# 0b11010
# 0b11000
# 0b10000
# 0b0
# 4
